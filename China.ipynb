# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Reading csv file
df = pd.read_csv('china station.csv')

# %%
#To get a quick overview of the size of the dataset.
df.shape
# Out:
# (175320, 18)

# %%
#shows the first few rows of the DataFrame 
df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
df.dtype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/z_/8nnd83x57hq3_6mhm5sdlzpw0000gn/T/ipykernel_6310/2494035241.py in <module>
# ----> 1 df.dtype()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
#Returns the last 5 rows of the DataFrame
df.tail()
# Out:
#            No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 175315  35060  2017      2   28    19   13.0  37.0  3.0  36.0  400.0  60.0
# 175316  35061  2017      2   28    20   20.0  43.0  4.0  48.0  500.0  43.0
# 175317  35062  2017      2   28    21   16.0  33.0  5.0  39.0  500.0  50.0
# 175318  35063  2017      2   28    22   11.0  24.0  5.0  47.0  500.0  41.0
# 175319  35064  2017      2   28    23   15.0  27.0  5.0  53.0  600.0  33.0
#
#         TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# 175315  12.5  1013.5 -16.2   0.0   NW   2.4  Guanyuan
# 175316  11.6  1013.6 -15.1   0.0  WNW   0.9  Guanyuan
# 175317  10.8  1014.2 -13.3   0.0   NW   1.1  Guanyuan
# 175318  10.5  1014.4 -12.9   0.0  NNW   1.2  Guanyuan
# 175319   8.6  1014.1 -15.9   0.0  NNE   1.3  Guanyuan

# %%
#Access specific rows and columns of the DataFrame
df.iloc[35065:350610,:]
# Out:
#            No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 35065       2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0
# 35066       3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0
# 35067       4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0
# 35068       5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0
# 35069       6  2013      3    1     5    3.0   3.0  10.0  17.0  400.0  71.0
# ...       ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 175315  35060  2017      2   28    19   13.0  37.0   3.0  36.0  400.0  60.0
# 175316  35061  2017      2   28    20   20.0  43.0   4.0  48.0  500.0  43.0
# 175317  35062  2017      2   28    21   16.0  33.0   5.0  39.0  500.0  50.0
# 175318  35063  2017      2   28    22   11.0  24.0   5.0  47.0  500.0  41.0
# 175319  35064  2017      2   28    23   15.0  27.0   5.0  53.0  600.0  33.0
#
#         TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# ...

# %%
#Count of unique values in column
df['wd'].value_counts()
# Out:
# NE     17262
# NNW    14423
# ENE    14371
# NW     13862
# E      13634
# N      13551
# ESE    11712
# SW     10959
# NNE    10656
# WNW     9303
# SSW     8401
# SE      8208
# WSW     7601
# S       7555
# SSE     7152
# W       6150
# Name: wd, dtype: int64

# %%
#Array of unique values to find the station name
df['RAIN'].unique()
# Out:
# array([ 0. ,  0.1,  0.4,  0.9,  0.2,  0.7,  1.4,  1.8,  1.5,  1.3,  1. ,
#         1.6,  2.5,  1.9,  1.1,  0.3,  0.8,  0.5,  0.6,  1.2, 10.7,  3.3,
#         2.2,  7.6,  8.9,  3.2,  2.1,  3.8,  3.6,  4. , 16. ,  5.7, 11.7,
#        21. , 10.1,  6.4,  2.4,  1.7,  2. ,  4.4, 12.1,  6.6,  2.8, 11.2,
#         3. ,  4.1,  3.1,  9.8,  8.8,  4.5, 14.7,  2.3, 10.6,  2.9,  6. ,
#        72.5,  6.8,  3.9,  8.6, 10.9,  3.5,  7. ,  7.3, 11.5, 11.6,  8.2,
#         5.4,  4.6,  7.8, 14.6, 40.7,  7.5, 23.6, 23.3,  6.5,  6.1, 26.8,
#         8. ,  5.2,  3.4,  2.6, 11.3, 12.9, 13.6,  3.7,  4.7,  4.2,  nan,
#         5. ,  2.7,  9.9,  4.8,  5.3,  9.6, 33.7, 15.4,  9.5, 29.3,  7.9,
#         7.2, 17.8, 33.1,  6.9,  5.9, 11.8,  4.3, 36.6, 13.4,  6.3,  4.9,
#        17.9,  7.1, 13.8, 23.7, 24.1, 20.3, 20.2,  9. , 16.4, 17.7, 18.3,
#        17.6, 15.3,  5.5, 21.7, 46.4, 14. ,  5.1, 22.3,  5.6,  7.7, 15.8,
#        18.4, 25.3,  8.5, 13.2,  8.1, 12.3, 13.3, 11.4, 21.6, 11. , 14.5,
# ...

# %%
#summary of the dataset 
df.describe()
# Out:
#                   No          year          month            day  \
# count  175320.000000  175320.00000  175320.000000  175320.000000
# mean    17532.500000    2014.66256       6.522930      15.729637
# std     10122.133783       1.17720       3.448713       8.800117
# min         1.000000    2013.00000       1.000000       1.000000
# 25%      8766.750000    2014.00000       4.000000       8.000000
# 50%     17532.500000    2015.00000       7.000000      16.000000
# 75%     26298.250000    2016.00000      10.000000      23.000000
# max     35064.000000    2017.00000      12.000000      31.000000
#
#                 hour          PM2.5           PM10            SO2  \
# count  175320.000000  171476.000000  172382.000000  171890.000000
# mean       11.500000      77.799974     101.572651      16.042345
# std         6.922206      79.436749      90.510711      21.511385
# min         0.000000       2.000000       2.000000       0.285600
# ...

# %%
#count of null values in each column 
df.isnull().sum()
# Out:
# No             0
# year           0
# month          0
# day            0
# hour           0
# PM2.5       3844
# PM10        2938
# SO2         3430
# NO2         5184
# CO         10259
# O3          5374
# TEMP         166
# PRES         160
# DEWP         166
# RAIN         162
# wd           520
# WSPM         128
# station        0
# dtype: int64

# %%
nan_count= df.isna().sum().sum()
print("Number of 'NaN' occurrences 2:", nan_count)
# Out:
# Number of 'NaN' occurrences 2: 32331

# %%
#Removing all rows with missing values (NaN) from the dataframe and storing the updated dataframe in a new variable called updated_data

updated_data = df.dropna()

# %%
#Replaces all occurrences of 'NaN' 
#updated_data=df.fillna(0,inplace=True)
#updated_data=df
#updated_data
# Out:
#            No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0           1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1           2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2           3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3           4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4           5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...       ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 175315  35060  2017      2   28    19   13.0  37.0   3.0  36.0  400.0  60.0
# 175316  35061  2017      2   28    20   20.0  43.0   4.0  48.0  500.0  43.0
# 175317  35062  2017      2   28    21   16.0  33.0   5.0  39.0  500.0  50.0
# 175318  35063  2017      2   28    22   11.0  24.0   5.0  47.0  500.0  41.0
# 175319  35064  2017      2   28    23   15.0  27.0   5.0  53.0  600.0  33.0
#
# ...

# %%
#checking duplpicates
updated_data.duplicated().sum().sum()
# Out:
# 0

# %%
updated_data.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
#count of occurrences of 'NaN'
nan_count= (updated_data.isna().sum().sum())
            
print("Number of 'NaN' occurrences :", nan_count)
# Out:
# Number of 'NaN' occurrences : 0

# %%
#Before droping Unwanted colums
updated_data
# Out:
#            No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0           1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1           2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2           3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3           4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4           5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...       ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 175315  35060  2017      2   28    19   13.0  37.0   3.0  36.0  400.0  60.0
# 175316  35061  2017      2   28    20   20.0  43.0   4.0  48.0  500.0  43.0
# 175317  35062  2017      2   28    21   16.0  33.0   5.0  39.0  500.0  50.0
# 175318  35063  2017      2   28    22   11.0  24.0   5.0  47.0  500.0  41.0
# 175319  35064  2017      2   28    23   15.0  27.0   5.0  53.0  600.0  33.0
#
# ...

# %%
updated_data.shape
# Out:
# (158403, 18)

# %%
#Droping unwanted colums 
updated_data.drop(['wd'], axis='columns', inplace=True)

#checking if its droped by using descriptive statistics 
updated_data.describe()
# Out:
# /var/folders/z_/8nnd83x57hq3_6mhm5sdlzpw0000gn/T/ipykernel_6310/2796938770.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   updated_data.drop(['wd'], axis='columns', inplace=True)
#                   No           year          month            day  \
# count  158403.000000  158403.000000  158403.000000  158403.000000
# mean    18110.804499    2014.734330       6.454303      15.708825
# std      9941.515283       1.150802       3.444856       8.778941
# min         1.000000    2013.000000       1.000000       1.000000
# 25%      9958.000000    2014.000000       3.000000       8.000000
# 50%     18327.000000    2015.000000       6.000000      16.000000
# 75%     26577.500000    2016.000000       9.000000      23.000000
# max     35064.000000    2017.000000      12.000000      31.000000
#
# ...

# %%
#shows the first few rows of the DataFrame to check if its removed
updated_data.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN  WSPM       station
# 0  1023.0 -18.8   0.0   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0   2.0  Aotizhongxin

# %%
#shows the last few rows of the DataFrame
updated_data.tail()
# Out:
#            No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 175315  35060  2017      2   28    19   13.0  37.0  3.0  36.0  400.0  60.0
# 175316  35061  2017      2   28    20   20.0  43.0  4.0  48.0  500.0  43.0
# 175317  35062  2017      2   28    21   16.0  33.0  5.0  39.0  500.0  50.0
# 175318  35063  2017      2   28    22   11.0  24.0  5.0  47.0  500.0  41.0
# 175319  35064  2017      2   28    23   15.0  27.0  5.0  53.0  600.0  33.0
#
#         TEMP    PRES  DEWP  RAIN  WSPM   station
# 175315  12.5  1013.5 -16.2   0.0   2.4  Guanyuan
# 175316  11.6  1013.6 -15.1   0.0   0.9  Guanyuan
# 175317  10.8  1014.2 -13.3   0.0   1.1  Guanyuan
# 175318  10.5  1014.4 -12.9   0.0   1.2  Guanyuan
# 175319   8.6  1014.1 -15.9   0.0   1.3  Guanyuan

# %%
#calculate the sum of missing values in each column
updated_data.isnull().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# WSPM       0
# station    0
# dtype: int64

# %%
updated_data
# Out:
#            No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0           1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1           2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2           3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3           4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4           5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...       ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 175315  35060  2017      2   28    19   13.0  37.0   3.0  36.0  400.0  60.0
# 175316  35061  2017      2   28    20   20.0  43.0   4.0  48.0  500.0  43.0
# 175317  35062  2017      2   28    21   16.0  33.0   5.0  39.0  500.0  50.0
# 175318  35063  2017      2   28    22   11.0  24.0   5.0  47.0  500.0  41.0
# 175319  35064  2017      2   28    23   15.0  27.0   5.0  53.0  600.0  33.0
#
#         TEMP    PRES  DEWP  RAIN  WSPM       station
# ...

# %%
from sklearn.preprocessing import LabelEncoder

#Convert the categorical values in the 'station' column of the 'updated_data' DataFrame into numerical values.

updated_data['station'] = updated_data['station'].astype('category')
labelencoder = LabelEncoder()
updated_data['station'] = labelencoder.fit_transform(updated_data['station'])
# Out:
# /var/folders/z_/8nnd83x57hq3_6mhm5sdlzpw0000gn/T/ipykernel_6310/2783804801.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   updated_data['station'] = updated_data['station'].astype('category')
# /var/folders/z_/8nnd83x57hq3_6mhm5sdlzpw0000gn/T/ipykernel_6310/2783804801.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   updated_data['station'] = labelencoder.fit_transform(updated_data['station'])

# %%
#checking the categoricAL value changed
updated_data
# Out:
#            No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0           1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1           2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2           3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3           4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4           5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...       ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 175315  35060  2017      2   28    19   13.0  37.0   3.0  36.0  400.0  60.0
# 175316  35061  2017      2   28    20   20.0  43.0   4.0  48.0  500.0  43.0
# 175317  35062  2017      2   28    21   16.0  33.0   5.0  39.0  500.0  50.0
# 175318  35063  2017      2   28    22   11.0  24.0   5.0  47.0  500.0  41.0
# 175319  35064  2017      2   28    23   15.0  27.0   5.0  53.0  600.0  33.0
#
#         TEMP    PRES  DEWP  RAIN  WSPM  station
# ...

# %%
#Gives data types of each column 
updated_data.dtypes
# Out:
# No           int64
# year         int64
# month        int64
# day          int64
# hour         int64
# PM2.5      float64
# PM10       float64
# SO2        float64
# NO2        float64
# CO         float64
# O3         float64
# TEMP       float64
# PRES       float64
# DEWP       float64
# RAIN       float64
# WSPM       float64
# station      int64
# dtype: object

# %%
#Gives a summary of a Pandas DataFrame
updated_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158403 entries, 0 to 175319
# Data columns (total 17 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   No       158403 non-null  int64
#  1   year     158403 non-null  int64
#  2   month    158403 non-null  int64
#  3   day      158403 non-null  int64
#  4   hour     158403 non-null  int64
#  5   PM2.5    158403 non-null  float64
#  6   PM10     158403 non-null  float64
#  7   SO2      158403 non-null  float64
#  8   NO2      158403 non-null  float64
#  9   CO       158403 non-null  float64
#  10  O3       158403 non-null  float64
#  11  TEMP     158403 non-null  float64
#  12  PRES     158403 non-null  float64
#  13  DEWP     158403 non-null  float64
#  14  RAIN     158403 non-null  float64
#  15  WSPM     158403 non-null  float64
#  16  station  158403 non-null  int64
# dtypes: float64(11), int64(6)
# memory usage: 21.8 MB

# %%
updated_data
# Out:
#            No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0           1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1           2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2           3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3           4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4           5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...       ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 175315  35060  2017      2   28    19   13.0  37.0   3.0  36.0  400.0  60.0
# 175316  35061  2017      2   28    20   20.0  43.0   4.0  48.0  500.0  43.0
# 175317  35062  2017      2   28    21   16.0  33.0   5.0  39.0  500.0  50.0
# 175318  35063  2017      2   28    22   11.0  24.0   5.0  47.0  500.0  41.0
# 175319  35064  2017      2   28    23   15.0  27.0   5.0  53.0  600.0  33.0
#
#         TEMP    PRES  DEWP  RAIN  WSPM  station
# ...

# %%
#updated_data['SO2'].unique()
updated_data['SO2'].value_counts()
# Out:
# 2.0000      37617
# 3.0000      11952
# 4.0000       8606
# 5.0000       7299
# 6.0000       6663
#             ...
# 7.4256          1
# 3.7128          1
# 5.9976          1
# 11.9952         1
# 293.0000        1
# Name: SO2, Length: 329, dtype: int64

# %%
columns = ['SO2','NO2','CO','O3','RAIN','WSPM','DEWP']  # list of column names to be processed
#Replacing special character and changin to float type
for col in columns:
    updated_data[col] = updated_data[col].astype(str).str.replace('#', '').str.replace('*', '').str.replace('x', '').astype(float)
# Out:
# /var/folders/z_/8nnd83x57hq3_6mhm5sdlzpw0000gn/T/ipykernel_6310/3396158138.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   updated_data[col] = updated_data[col].astype(str).str.replace('#', '').str.replace('*', '').str.replace('x', '').astype(float)
# /var/folders/z_/8nnd83x57hq3_6mhm5sdlzpw0000gn/T/ipykernel_6310/3396158138.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   updated_data[col] = updated_data[col].astype(str).str.replace('#', '').str.replace('*', '').str.replace('x', '').astype(float)

# %%
#Gives a summary of a Pandas DataFrame
updated_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175320 entries, 0 to 175319
# Data columns (total 18 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   No       175320 non-null  int64
#  1   year     175320 non-null  int64
#  2   month    175320 non-null  int64
#  3   day      175320 non-null  int64
#  4   hour     175320 non-null  int64
#  5   PM2.5    175320 non-null  float64
#  6   PM10     175320 non-null  float64
#  7   SO2      175320 non-null  float64
#  8   NO2      175320 non-null  float64
#  9   CO       175320 non-null  float64
#  10  O3       175320 non-null  float64
#  11  TEMP     175320 non-null  float64
#  12  PRES     175320 non-null  float64
#  13  DEWP     175320 non-null  float64
#  14  RAIN     175320 non-null  float64
#  15  wd       175320 non-null  object
#  16  WSPM     175320 non-null  float64
#  17  station  175320 non-null  int64
# dtypes: float64(11), int64(6), object(1)
# memory usage: 24.1+ MB

# %%
#Time SERIES 
plt.plot(updated_data['year'],updated_data['NO2'])

plt.xlabel('year')
plt.ylabel('Air Quality Index')
plt.title('Air Quality Index over year')
plt.show()

# %%
#Computescorrelation matrix for the updated_data DataFrame
co = updated_data.corr()

# %%
#generates a heatmap using the 'co' data
sns.heatmap(co, annot = True, fmt='.1g')
# Out:
# <AxesSubplot:>

# %%
pivot_table = pd.pivot_table(updated_data, values='CO', index='month', columns=['TEMP', 'O3', 'PRES'])


# Create a heatmap using the pivot table
sns.heatmap(pivot_table, cmap='coolwarm')

# Set the title and axis labels
plt.title('Air Quality Index by NO and Month')
plt.xlabel('NO')
plt.ylabel('Month')
# Out:
# Text(50.722222222222214, 0.5, 'Month')

# %%
plt.scatter(updated_data['hour'], updated_data['NO2'])
plt.xlabel('HOUR')
plt.ylabel('Air Quality Index')
plt.title('Air Quality Index over time in hrs')
plt.show()

# %%
#Creating the box plot
plt.boxplot(updated_data['SO2'])
plt.boxplot(updated_data['NO2'])
plt.boxplot(updated_data['CO'])

# set the x-axis label
plt.xlabel('')

# set the y-axis label
plt.ylabel('Air Quality Index')

# set the plot title
plt.title('Air Quality Index Box Plot')

# display the plot
plt.show()

# %%
#Descriptive statistics of the updated data, rounded to one decimal place.
updated_data.describe().round(1)
# Out:
#              No      year     month       day      hour     PM2.5      PM10  \
# count  158403.0  158403.0  158403.0  158403.0  158403.0  158403.0  158403.0
# mean    18110.8    2014.7       6.5      15.7      11.5      77.3     101.5
# std      9941.5       1.2       3.4       8.8       6.9      78.6      90.1
# min         1.0    2013.0       1.0       1.0       0.0       3.0       2.0
# 25%      9958.0    2014.0       3.0       8.0       6.0      19.0      34.0
# 50%     18327.0    2015.0       6.0      16.0      12.0      52.0      78.0
# 75%     26577.5    2016.0       9.0      23.0      18.0     108.0     141.0
# max     35064.0    2017.0      12.0      31.0      23.0     713.0     992.0
#
#             SO2       NO2        CO        O3      TEMP      PRES      DEWP  \
# count  158403.0  158403.0  158403.0  158403.0  158403.0  158403.0  158403.0
# mean       15.7      48.4    1181.1      59.1      13.6    1010.4       2.3
# ...

# %%
#Returns a tuple containing the number of rows and columns 
updated_data.shape
# Out:
# (158403, 17)

# %%
#Caption: "Displaying the last few rows 
updated_data.tail()
# Out:
#            No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 175315  35060  2017      2   28    19   13.0  37.0  3.0  36.0  400.0  60.0
# 175316  35061  2017      2   28    20   20.0  43.0  4.0  48.0  500.0  43.0
# 175317  35062  2017      2   28    21   16.0  33.0  5.0  39.0  500.0  50.0
# 175318  35063  2017      2   28    22   11.0  24.0  5.0  47.0  500.0  41.0
# 175319  35064  2017      2   28    23   15.0  27.0  5.0  53.0  600.0  33.0
#
#         TEMP    PRES  DEWP  RAIN  WSPM  station
# 175315  12.5  1013.5 -16.2   0.0   2.4        4
# 175316  11.6  1013.6 -15.1   0.0   0.9        4
# 175317  10.8  1014.2 -13.3   0.0   1.1        4
# 175318  10.5  1014.4 -12.9   0.0   1.2        4
# 175319   8.6  1014.1 -15.9   0.0   1.3        4

# %%
updated_data
# Out:
#            No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0           1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1           2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2           3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3           4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4           5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...       ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 175315  35060  2017      2   28    19   13.0  37.0   3.0  36.0  400.0  60.0
# 175316  35061  2017      2   28    20   20.0  43.0   4.0  48.0  500.0  43.0
# 175317  35062  2017      2   28    21   16.0  33.0   5.0  39.0  500.0  50.0
# 175318  35063  2017      2   28    22   11.0  24.0   5.0  47.0  500.0  41.0
# 175319  35064  2017      2   28    23   15.0  27.0   5.0  53.0  600.0  33.0
#
#         TEMP    PRES  DEWP  RAIN   wd  WSPM  station
# ...

# %%
updated_data.isnull()
# Out:
#            No   year  month    day   hour  PM2.5   PM10    SO2    NO2     CO  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 175315  False  False  False  False  False  False  False  False  False  False
# 175316  False  False  False  False  False  False  False  False  False  False
# 175317  False  False  False  False  False  False  False  False  False  False
# 175318  False  False  False  False  False  False  False  False  False  False
# 175319  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
X = updated_data[['CO','O3','SO2','NO2','TEMP','WSPM','DEWP']]
y = updated_data['station']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled[0]
# Out:
# array([-0.77930614,  0.31590416, -0.55601967, -1.19423698, -1.25825891,
#         2.06105774, -1.53169367])

# %%
from sklearn.model_selection import train_test_split

# %%
#Splitting the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X_scaled, y, train_size = 0.8, random_state = 42)#train size of 80%

# %% [markdown]
# ### Algorithm - 1, K Nearest Neighbours (KNN)regression

# %% [markdown]
# #### Model 1

# %%
#test1 :count of occurrences of 'NR'
nan_count= updated_data.isna().sum().sum()
print("Number of 'NaN' occurrences :", nan_count)
# Out:
# Number of 'NaN' occurrences : 0

# %%
#Replaces all occurrences of 'NaN' 
updated_data.fillna(0,inplace=True)
updated_data
# Out:
#            No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0           1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1           2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2           3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3           4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4           5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...       ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 175315  35060  2017      2   28    19   13.0  37.0   3.0  36.0  400.0  60.0
# 175316  35061  2017      2   28    20   20.0  43.0   4.0  48.0  500.0  43.0
# 175317  35062  2017      2   28    21   16.0  33.0   5.0  39.0  500.0  50.0
# 175318  35063  2017      2   28    22   11.0  24.0   5.0  47.0  500.0  41.0
# 175319  35064  2017      2   28    23   15.0  27.0   5.0  53.0  600.0  33.0
#
#         TEMP    PRES  station
# ...

# %%
#test2 :count of occurrences of 'NaN'
nan_count= updated_data.isna().sum().sum()
print("Number of 'NaN' occurrences :", nan_count)
# Out:
# Number of 'NaN' occurrences : 0

# %%
updated_data.isnull()

# check for non-missing values using notnull() function
updated_data.notnull()
# Out:
#           No  year  month   day  hour  PM2.5  PM10   SO2   NO2    CO    O3  \
# 0       True  True   True  True  True   True  True  True  True  True  True
# 1       True  True   True  True  True   True  True  True  True  True  True
# 2       True  True   True  True  True   True  True  True  True  True  True
# 3       True  True   True  True  True   True  True  True  True  True  True
# 4       True  True   True  True  True   True  True  True  True  True  True
# ...      ...   ...    ...   ...   ...    ...   ...   ...   ...   ...   ...
# 175315  True  True   True  True  True   True  True  True  True  True  True
# 175316  True  True   True  True  True   True  True  True  True  True  True
# 175317  True  True   True  True  True   True  True  True  True  True  True
# 175318  True  True   True  True  True   True  True  True  True  True  True
# 175319  True  True   True  True  True   True  True  True  True  True  True
#
#         TEMP  PRES  DEWP  RAIN    wd  WSPM  station
# ...

# %%
updated_data=updated_data.describe().round(1)

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Create a KNN Regression object with k=5
knn_model = KNeighborsRegressor(n_neighbors=5)

# %%
# Fit the model to the training data
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
# Predict the target variable for the test data
y_pred = knn_model.predict(x_test)

# Evaluate the model using mean squared error and R-squared metrics
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE): {:.2f}".format(mse))
print("R-squared (R2): {:.2f}".format(r2))
# Out:
# Mean Squared Error (MSE): 1.89
# R-squared (R2): 0.05

# %% [markdown]
# #### model 2

# %%
from sklearn.neighbors import RadiusNeighborsRegressor

# Create a Radius Neighbors Regression object with radius=1.0
rnn_model = RadiusNeighborsRegressor(radius=1.0)

# Fit the model to the training data
rnn_model.fit(x_train, y_train)

# Predict the target variable for the test data
y_pred = rnn_model.predict(x_test)

# Evaluate the model using mean squared error and R-squared metrics
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE): {:.2f}".format(mse))
print("R-squared (R2 ): {:.2f}".format(r2))
# Out:
# Mean Squared Error (MSE): 50949190803528598682603569180311552.00
# R-squared (R2 ): -25477682354574297282094670433746944.00

# %% [markdown]
# ### Algorithm - 2, Random Forest

# %% [markdown]
# #### Model 1

# %%
#Importing the `RandomForestClassifier` class from the `sklearn.ensemble` module.
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
from sklearn.ensemble import RandomForestRegressor

# create a Random Forest Regressor model
rf = RandomForestRegressor(n_estimators=100, random_state=42)

# fit the model on the training data
rf.fit(x_train, y_train)

# make predictions on the test data
y_pred = rf.predict(x_test)

# evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE): {:.2f}".format(mse))
print("R-squared (R2): {:.2f}".format(r2))
# Out:
# Mean Squared Error (MSE): 1.65
# R-squared (R2): 0.18

# %%
import math
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Instantiate a RandomForestClassifier
rfc = RandomForestClassifier()

# Fit the RandomForestClassifier model on the training data
model = rfc.fit(x_train, y_train)

# Calculate the accuracy of the model on the training data
train_accuracy = model.score(x_train, y_train)

# Calculate the accuracy of the model on the test data
test_accuracy = model.score(x_test, y_test)

# Predict the target variable using the trained model
y_pred = model.predict(x_test)

# Calculate the Root Mean Square Error (RMSE)
MSE = np.square(np.subtract(y_test, y_pred)).mean()
RMSE = math.sqrt(MSE)

# Calculate additional evaluation metrics
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
confusion_mat = confusion_matrix(y_test, y_pred)

# Print the evaluation results
print("Train Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)
print("Root Mean Square Error:", RMSE)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion Matrix:\n", confusion_mat)
# Out:
# Train Accuracy: 0.9999053045248655
# Test Accuracy: 0.510432120198226
# Root Mean Square Error: 1.6787364273615857
# Precision: 0.5079490482381119
# Recall: 0.510432120198226
# F1 Score: 0.509060666176065
# Confusion Matrix:
#  [[2949  643  380  871 1356]
#  [ 620 3387 1113  756  642]
#  [ 318 1024 4448  325  207]
#  [ 822  871  429 2665 1398]
#  [1396  669  288 1382 2722]]

# %% [markdown]
# #### Model 2 - Using H2O

# %%
#Installing H2O using pip package manager
# !pip install h2o

# %%
#Importing the H2O Random Forest Estimator module from the H2O package.
from h2o.estimators import H2ORandomForestEstimator

# %%
import h2o
from h2o.estimators import H2ORandomForestEstimator
h2o.init()
h2o_frame = h2o.H2OFrame(updated_data)
type(h2o_frame)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  ---------------------------------
# H2O_cluster_uptime:         2 days 22 hours 42 mins
# H2O_cluster_timezone:       Europe/Dublin
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.40.0.4
# H2O_cluster_version_age:    7 days, 1 hour and 36 minutes
# H2O_cluster_name:           H2O_from_python_macbookair_5prfs9
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    1.921 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.9.13 final
# --------------------------  ---------------------------------
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# ...

# %%
import h2o
from h2o.frame import H2OFrame

h2o.init() # initialize h2o
h2o_frame = h2o.H2OFrame(updated_data)
type(h2o_frame)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  ---------------------------------
# H2O_cluster_uptime:         2 days 22 hours 42 mins
# H2O_cluster_timezone:       Europe/Dublin
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.40.0.4
# H2O_cluster_version_age:    7 days, 1 hour and 36 minutes
# H2O_cluster_name:           H2O_from_python_macbookair_5prfs9
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    1.921 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.9.13 final
# --------------------------  ---------------------------------
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# ...

# %%
#Returns a list of column names in the H2O frame 
h2o_frame.types
# Out:
# {'No': 'real',
#  'year': 'real',
#  'month': 'real',
#  'day': 'real',
#  'hour': 'real',
#  'PM2.5': 'real',
#  'PM10': 'real',
#  'SO2': 'real',
#  'NO2': 'real',
#  'CO': 'real',
#  'O3': 'real',
#  'TEMP': 'real',
#  'PRES': 'real',
#  'station': 'real'}

# %%
#Defining predictors and response variables for a model.
predictors = ['CO','NO2','SO2','O3','PRES','O3','TEMP','PM2.5','PM10','RAIN','WSPM','DEWP']
response = 'station'

# %%
data_split = h2o_frame.split_frame(ratios = [0.8], seed = 1234)
data_train = data_split[0] # using 80% for training
data_test = data_split[1]  # using the rest 20% for out-of-bag evaluation

# %%
rfc_model = H2ORandomForestEstimator(ntrees=10,
                                    max_depth=7,
                                    min_rows=3,
                                    seed=1234
                                    
                                    )

# %%
#Training a random forest classifier model on training data 
rfc_model.train(x=predictors,
                   y=response,
                   training_frame=data_train)
# Out:
# drf Model Build progress: |██████████████████████████████████████████████████████| (done) 100%
# Model Details
# ...
# H2ORandomForestEstimator : Distributed Random Forest
# Model Key: DRF_model_python_1683036136880_20
#
#
# Model Summary:
#     number_of_trees    number_of_internal_trees    model_size_in_bytes    min_depth    max_depth    mean_depth    min_leaves    max_leaves    mean_leaves
# --  -----------------  --------------------------  ---------------------  -----------  -----------  ------------  ------------  ------------  -------------
#     10                 10                          776                    1            1            0.4           1             2             1.4
#
# ModelMetricsRegression: drf
# ** Reported on train data. **
#
# MSE: 3755528246.7275534
# RMSE: 61282.364891765996
# MAE: 44803.476292786145
# RMSLE: 8.314218016772546
# Mean Residual Deviance: 3755528246.7275534
#
# Scoring History:
# ...

# %%
perf
# Out:
# ModelMetricsRegression: drf
# ** Reported on test data. **
#
# MSE: 225877373.9659625
# RMSE: 15029.217343759537
# MAE: 15029.217343759537
# RMSLE: 9.61781794330511
# Mean Residual Deviance: 225877373.9659625

# %% [markdown]
# ### Algorithm- 3, Support Vector Machines (SVM)

# %%
updated_data.duplicated().sum()
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.svm import SVR

# %%
#train SVM model
model = SVR(kernel='rbf')
model.fit(x_train, y_train)
# Out:
# SVR()

# %%
# evaluate model performance
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)

# %%
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Mean Squared Error (MSE)', mse)
print('Root Mean Squared Error (RMSE)', rmse)
print('Mean Absolute Error (MAE)', mae)
print("R^2 value: ", r2)
# Out:
# Mean Squared Error (MSE) 1.9436336526618647
# Root Mean Squared Error (RMSE) 1.3941426227835747
# Mean Absolute Error (MAE) 1.133141474019201
# R^2 value:  0.027629832263495246

# %% [markdown]
# ### Algorithm- 4, Artificial neural networks (ANN)

# %%
pip install keras

# %%
pip install tensorflow

# %%
from tensorflow import keras
# Out:
# 2023-05-05 20:45:33.380332: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from keras.models import Sequential
from keras.layers import Dense

from sklearn.metrics import r2_score

# %%
# define the model
model = Sequential()
model.add(Dense(10, input_dim=x_train.shape[1], activation='relu'))
model.add(Dense(1, activation='linear'))

# compile the model
model.compile(loss='mean_squared_error', optimizer='adam')

# fit the model to the training data
history = model.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=0)

# %%
# evaluate the model performance on the test data
loss = model.evaluate(x_test, y_test, verbose=0)
y_pred = model.predict(x_test)
r2 = r2_score(y_test, y_pred)

print('Mean Squared Error (MSE)', loss)
print("R^2 value: ", r2)
# Out:
# 991/991 [==============================] - 2s 2ms/step
# Mean Squared Error (MSE) 1.9288702011108398
# R^2 value:  0.03501584012518866
